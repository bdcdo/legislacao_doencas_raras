# %%
import pandas as pd

# %%
df = pd.read_csv('05_legislacao_candidatos_revisao_manual.csv')

# %%
df.columns
# Out:
# Index(['nome', 'link', 'ficha', 'revogacao', 'descricao', 'termo_busca',
#        'link_content', 'ficha_content', 'infos_completas', 'medicamento',
#        'patologias', 'órfão,', 'terapia', 'ultrarrara', 'terapias', 'raras,',
#        'ultrarrara,', 'doença', 'medicamentos', 'órfãs', 'órfã', 'rara',
#        'síndromes', 'rara,', 'síndrome', 'órfã,', 'doenças', 'ultrarraras,',
#        'patologia', 'órfãos', 'órfão', 'órfãos,', 'raras', 'ultrarraras'],
#       dtype='object')

# %%
df[['nome', 'link', 'ficha', 'revogacao', 'descricao']].to_excel('base_final.xlsx')
